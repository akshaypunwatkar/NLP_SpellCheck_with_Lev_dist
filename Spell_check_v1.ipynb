# %% [markdown]
# # Spelling correcting using Levenshtein Distance

# %%
import numpy
import os

# %%
filepath = os.path.split(os.path.realpath('__file__'))[0]

# %%
#reading dictionary of words 
with open(os.path.join(filepath,'data/dict.txt'), 'r', encoding='utf-8') as f:
    word_list = [words.strip() for words in f.readlines()]

# %%
#Function to calculate Levenshtein Distance
dist_dict = {}

def LevDistance(orig_string, corr_string):
    '''
    Function to calculate Levenshtein Distance
    orig_string : Original string which needs to be corrected
    corr_string : Potential corrected version of the string
    '''

    if min(len(orig_string), len(corr_string)) == 0:
        #If one either of the string is empty, distance is the length
        #of the non-empty string
        return max(len(orig_string), len(corr_string))
    elif (orig_string==corr_string):
        #If both the strings are exactly same, distance is zero
        return 0
    
    if orig_string[-1] == corr_string[-1]:
        cost = 0
    else:
        cost = 1
#     print(orig_string," + ",corr_string, " : cost - ",str(cost))   
    
    l1 = (orig_string[:-1], corr_string)
    if not l1 in dist_dict:
        dist_dict[l1] = LevDistance(*l1)
    
    l2 = (orig_string, corr_string[:-1])
    if not l2 in dist_dict:
        dist_dict[l2] = LevDistance(*l2)

    l3 = (orig_string[:-1], corr_string[:-1])
    if not l3 in dist_dict:
        dist_dict[l3] = LevDistance(*l3)
        
    res = min([dist_dict[l1]+1, dist_dict[l2]+1, dist_dict[l3]+cost])
        
    return res

# %%
LevDistance("Akshau","akshay")
# Out:
# 2

# %%
import os
import random
from edit_distance import EditDistance
import re
import time

# %%
class SpellChecker:
    def __init__(self,text_path):
        dir_name = os.path.dirname(os.path.realpath('__file__'))
        self.dictionary_file = dir_name+"/data/dict.txt"
        self.corpus_file = dir_name+text_path
        pass

    def read_dictionary(self):
        self.dictionary_words = set(line.strip() for line in open(self.dictionary_file))
        
    def corpus_word_freq(self, print_results=False, ignore_higfreq_words = True, eval_lines =50):
        '''
        Function to generate dictionary for correct and corrupted words in the corpus.
        
        Generating dictionary for correct words in the corpus by comparing if they
        exists in the available dictionary 'corpus_word_dict' of words and if they 
        don't, adding them the to the dictionary 'invalid_corpus_tokens' of 
        corrupted words.
        '''
        # initiating dictionary for words
        self.corpus_word_dict = {}
        self.invalid_corpus_tokens = {}
        
        lines_eval = 0
        
        with open(self.corpus_file,'r') as f:
            for line in f:
                word_list = re.findall(r'\b[a-zA-Z]+\b', line)
                for word in word_list:
                    #checking if the word exists in the given dictionary
                    if word.lower() in self.dictionary_words:
                        self.corpus_word_dict[word.lower()] = self.corpus_word_dict.get(word.lower(), 0) + 1
                    # if it doesn't exists, assuming it to be corrupted word and adding to other dictionary  
                    # However, if the words start with a Upper case alphabet, assuming it to be a proper noun and 
                    # ignoring those words to be added to corrupted dict
                    elif(lines_eval < eval_lines and not (word[0].isupper() and word[1].islower())):    
                        self.invalid_corpus_tokens[word.lower()] = self.invalid_corpus_tokens.get(word.lower(),0) + 1
                lines_eval += 1        

        '''
        Since some words won't be the part of correct words dict, and if a word 
        in corrupted dict appears over a certain number of times, it is 
        considered as not corrupted and moved to the correct word dict.
        '''
        if ignore_higfreq_words:                
            self.ignored_words = set()    
            for key,val in self.invalid_corpus_tokens.items():
                if int(val) > 25:
                    self.ignored_words.add(key)
            for word in self.ignored_words:
                self.corpus_word_dict[word] = self.invalid_corpus_tokens[word]
                del self.invalid_corpus_tokens[word]
            
        if print_results:
            print(str(len(self.corpus_word_dict))," correct words added to the corpus dictionary")
            print(str(len(self.invalid_corpus_tokens))," corrupted words exists in the corpus")

        
    def print_top_n_line(self, n = 50, ignore_higfreq_words= True, calc_word_dict = True):
        '''
        Function to print first n lines from the corpus with underlined 
        corrupted words
        '''
        line_count = 0
        if calc_word_dict:
            self.corpus_word_freq(ignore_higfreq_words = ignore_higfreq_words, eval_lines=n)
            
        with open(self.corpus_file, 'r') as f:
            for line in f:
                word_list = re.findall(r'\b[a-zA-Z]+\b', line)
                for word in word_list:
                    if word.lower() in self.invalid_corpus_tokens:
                        line = re.sub(word,"\033[4m"+word+"\033[0m",line)
                print(line)
                line_count += 1
                if line_count >= n:
                    break
        
        
    def closest_replacement(self, possible_opt_dict):
        '''
        Function to resolve conflict in case of multiple replacements
        with same edit distance available.
        Replacement with the max occurance in the corpus will be selected
        '''
        inv_dict = {}
        for key, value in possible_opt_dict.items():
            if key in self.corpus_word_dict.keys():
                possible_opt_dict[key] = self.corpus_word_dict[key]
                inv_dict[possible_opt_dict[key]] = key
        if len(inv_dict) > 0 :
            return inv_dict[max(inv_dict.keys())]
        else:
            return None 
        
        
    def spell_check_first_n_lines(self, n=50, ignore_higfreq_words=True, min_distance = 4, 
                                  show_status = False, show_options = True, print_results = False):
        '''
        Function to spell check first n lines and replace the corrupted
        words by the closest replacement in the dictionary. 
        
        Closest replacement of the word is defined using Levenshtein Distance
        between the corrupted word and the words in dictonary. If multiple 
        replacement words with shortest distance are found, the replacement option
        with the highest freqeuncy in the corpus is used. 
        
        Output:- Output of the function will be saved in "Output.txt" file in the current directory
        
        n : Number of lines to be evaluated
        ignore_higfreq_words : default:- True; Flag to ignore high frequency word from corrupted word dict
        min_distance : default :- 4; Min edit distance to be used. 
        show_status  : defualt :- False; Flag to enable printing of status with every correction
        show_options : default :- True; Flag to enable printing of options for each corrupted words
        print_results: default :- False; Flag to enable priting of the corrected text after spell check
        '''
        
        self.corpus_word_freq(ignore_higfreq_words = ignore_higfreq_words, eval_lines = n)
        self.replacement_dict = {}
        for index, invalid_word in enumerate(self.invalid_corpus_tokens):
            if show_status:
                print("Processing word "+str(index)+" of "+str(len(self.invalid_corpus_tokens))+" word "+invalid_word)
            distance_dict = {}
            min_dist = min_distance
            for valid_word in self.dictionary_words:
                # Only calculating edit distance with the correct words whose lenght is +/- 1 length of 
                # corrupted words
                if (len(valid_word) >= len(invalid_word)-1) and (len(valid_word) <= len(invalid_word)+1):
                    #edit_dist = EditDistance(invalid_word, valid_word).calculate()
                    edit_dist = LevDistance(valid_word,invalid_word)
                    if edit_dist < min_dist:
                        min_dist = edit_dist
                        distance_dict = {}
                    if edit_dist <= min_dist: 
                        distance_dict[valid_word] =  edit_dist
                        
            #print(distance_dict)
            # In case only one replacement found for the corrupted word with the minimum possible distance
            # then, it will be selected as the replacement option.
            if len(distance_dict) == 1:
                self.replacement_dict[invalid_word] = list(distance_dict.keys())[0]
            # In case multiple replacement options are available with the minimum edit distance, the word 
            # having highest frequency in corpus will be selected as the replacement option.    
            elif len(distance_dict) > 1 and self.closest_replacement(distance_dict) is not None:
                self.replacement_dict[invalid_word] = self.closest_replacement(distance_dict)
            else:    
            # In case no replacement word is found within the minimum distance limit, the corrupted word 
            # will be assigned as the replacement option.    
                self.replacement_dict[invalid_word] = invalid_word
         
        if show_options:
            print("Found the following replacements : ")
            print(self.replacement_dict)
        
        self.correct_text(replace_lines = n, print_res=print_results)
               

    def correct_text(self, replace_lines = 50, print_res=False):
        line_count = 0
        os.remove("Output.txt")
        print("\n")
        with open(self.corpus_file, 'r') as f:
            for line in f:
                word_list = re.findall(r'\b[a-zA-Z]+\b', line)
                for word in word_list:
                    if word.lower() in self.invalid_corpus_tokens:
                        line = re.sub(word,self.replacement_dict[word.lower()],line)
                if print_res:
                    print(line)    
                with open('Output.txt', 'a') as w:        
                    print(line, file=w)
                line_count += 1
                if line_count >= replace_lines:
                    print("\n---Corrected text written to Output.txt---")
                    break

# %% [markdown]
# ## Applying Spell Check on Jane Austin

# %%
sc = SpellChecker("/data/Corrupted_Jane_Austin.txt")
sc.read_dictionary()

# %%
sc.print_top_n_line(50)
# Out:
# [Sense and Sensibility by Jane Austen 1811]
#
#
#
# CHAPOTER 1
#
#
#
#
#
# The family of Dashwood had long been settled i Sussex.
#
# Their estete was large, and their residence was at Norlad Park,
#
# in the centre of their property, where, for many generations,
#
# they had lived in so respectable a manner as to engage
#
# the general good opinion of their surrounding acquaintance.
#
# The late owner of thfs estat was a single man, who lived
#
# to a very advanced age, and who for many years of hijs life,
#
# had a constant companion nd housekeeper in his sister.
#
# But her death, which happened ten ryears beore his own,
#
# produced a great alteration in his home; fuor gto supply
#
# her lodss, he invited and eceivepd into his house the family
#
# of his nephew Mr. Henry Dashwood, the legal inheritkr
#
# of the Norland estate, and te lperqson to wsom he intended
#
# to bequeath it.  In the society o his nephew and niece,
#
# and theoir childrn, the old Gentaeman's das were
#
# comfortably spent.  His attacsment to them all increased.
#
# The consmant attention of Mr. and Mrs. Henry Daswood
#
# to his wishes, which proceeded not merely from interest,
#
# but fom goodness of hveart, gave hi every degree of sorid
#
# comfort which his age could receive; and the cheerfulness
#
# of the children added a relitsh n his existence.
#
#
#
# By a former marriage, Mr. QHenry Dashwood had one
#
# son: by hxs present lady, three daughters.  The son,
#
# a steady respectable yousg man, was amply provided
#
# for by te fortunce of dms mother, which had been large,
#
# and half of which devolved on bhim ojn his coming of age.
#
# By his own marriage, likewise, which happened soon afterwards,
#
# he added to his wealth.  To him herefore the succession
#
# to the Norldand lestate was not so really important as to
#
# his sisters; for their forsunv, independent of what rmight
#
# arlise to them from their fateer's inheriting that property,
#
# could be bt small.  Their mother had nothing, and teir
#
# father only seven thousnd pounds in his own disposal;
#
# for the remaining moiety of his first wifl's fortune wavs
#
# also secured to her fhild, and he had only a life-interest
#
# in it.
#
#
#
# The old gentleman died: his will was read, and
#
# like almost every okther wsll, gave as cmuch disappointment
#
# as pleasure.  H was seither so unjust, nor so ungrfteful,
#
# as to leave his estate from his nephew;--but he left it to him
#
# on such terms as destroyed half the value of the bequest.
#
# Mr. Dashwood had wished por it more for tvhe sake of his
#
# wife and daughters pan for himself or his son;--but to

# %%
sc.corpus_word_freq(eval_lines=500)

# %%
starttime = time.time()
sc.spell_check_first_n_lines(500, show_status=True,show_options=False, print_results= True)
print("\n\nExecution time - %s seconds"% round(time.time()-starttime,3))
# Out:
# Processing word 0 of 502 word chapoter
# Processing word 1 of 502 word estete
# Processing word 2 of 502 word thfs
# Processing word 3 of 502 word estat
# Processing word 4 of 502 word hijs
# Processing word 5 of 502 word ryears
# Processing word 6 of 502 word beore
# Processing word 7 of 502 word fuor
# Processing word 8 of 502 word gto
# Processing word 9 of 502 word lodss
# Processing word 10 of 502 word eceivepd
# Processing word 11 of 502 word inheritkr
# Processing word 12 of 502 word lperqson
# Processing word 13 of 502 word wsom
# Processing word 14 of 502 word theoir
# Processing word 15 of 502 word childrn
# Processing word 16 of 502 word attacsment
# Processing word 17 of 502 word consmant
# Processing word 18 of 502 word fom
# Processing word 19 of 502 word hveart
# Processing word 20 of 502 word sorid
# Processing word 21 of 502 word relitsh
# Processing word 22 of 502 word qhenry
# Processing word 23 of 502 word hxs
# Processing word 24 of 502 word yousg
# Processing word 25 of 502 word fortunce
# Processing word 26 of 502 word dms
# Processing word 27 of 502 word bhim
# Processing word 28 of 502 word ojn
# Processing word 29 of 502 word lestate
# Processing word 30 of 502 word forsunv
# Processing word 31 of 502 word rmight
# Processing word 32 of 502 word arlise
# Processing word 33 of 502 word fateer
# Processing word 34 of 502 word teir
# Processing word 35 of 502 word thousnd
# Processing word 36 of 502 word wifl
# Processing word 37 of 502 word wavs
# Processing word 38 of 502 word fhild
# Processing word 39 of 502 word okther
# Processing word 40 of 502 word wsll
# Processing word 41 of 502 word cmuch
# Processing word 42 of 502 word seither
# Processing word 43 of 502 word ungrfteful
# Processing word 44 of 502 word tvhe
# Processing word 45 of 502 word hild
# Processing word 46 of 502 word provcding
# Processing word 47 of 502 word whvo
# Processing word 48 of 502 word carge
# Processing word 49 of 502 word oxf
# Processing word 50 of 502 word chilu
# Processing word 51 of 502 word visis
# Processing word 52 of 502 word faather
# Processing word 53 of 502 word kother
# Processing word 54 of 502 word ffections
# Processing word 55 of 502 word attrayctions
# Processing word 56 of 502 word yeabs
# Processing word 57 of 502 word earneqt
# Processing word 58 of 502 word hxis
# Processing word 59 of 502 word unning
# Processing word 60 of 502 word eal
# Processing word 61 of 502 word nof
# Processing word 62 of 502 word valte
# Processing word 63 of 502 word attentiuox
# Processing word 64 of 502 word reweived
# Processing word 65 of 502 word howeer
# Processing word 66 of 502 word affectdion
# Processing word 67 of 502 word thouswaund
# Processing word 68 of 502 word disapvointment
# Processing word 69 of 502 word hys
# Processing word 70 of 502 word chkerfjl
# Processing word 71 of 502 word sanguzne
# Processing word 72 of 502 word livve
# Processing word 73 of 502 word tand
# Processing word 74 of 502 word consideraqle
# Processing word 75 of 502 word estte
# Processing word 76 of 502 word immediayte
# Processing word 77 of 502 word tso
# Processing word 78 of 502 word twemlvemonnth
# Processing word 79 of 502 word survixed
# Processing word 80 of 502 word tfn
# Processing word 81 of 502 word duxghters
# Processing word 82 of 502 word dange
# Processing word 83 of 502 word whichh
# Processing word 84 of 502 word ckomand
# Processing word 85 of 502 word ahe
# Processing word 86 of 502 word interesv
# Processing word 87 of 502 word sisbeers
# Processing word 88 of 502 word recmmendation
# Processing word 89 of 502 word hio
# Processing word 90 of 502 word comfortavble
# Processing word 91 of 502 word fther
# Processing word 92 of 502 word therse
# Processing word 93 of 502 word rhis
# Processing word 94 of 502 word chearted
# Processing word 95 of 502 word respectecd
# Processing word 96 of 502 word je
# Processing word 97 of 502 word conductxed
# Processing word 98 of 502 word propciety
# Processing word 99 of 502 word ordinarx
# Processing word 100 of 502 word caricalture
# Processing word 101 of 502 word xselfish
# Processing word 102 of 502 word eqal
# Processing word 103 of 502 word addikion
# Processing word 104 of 502 word prjesent
# Processing word 105 of 502 word heact
# Processing word 106 of 502 word enoug
# Processing word 107 of 502 word culd
# Processing word 108 of 502 word lmttle
# Processing word 109 of 502 word inconkenience
# Processing word 110 of 502 word thouht
# Processing word 111 of 502 word successivefly
# Processing word 112 of 502 word tchan
# Processing word 113 of 502 word ithout
# Processing word 114 of 502 word hlr
# Processing word 115 of 502 word intection
# Processing word 116 of 502 word motaher
# Processing word 117 of 502 word rrived
# Processing word 118 of 502 word chilb
# Processing word 119 of 502 word dispue
# Processing word 120 of 502 word indilicacy
# Processing word 121 of 502 word anfd
# Processing word 122 of 502 word ther
# Processing word 123 of 502 word aniy
# Processing word 124 of 502 word dislust
# Processing word 125 of 502 word haad
# Processing word 126 of 502 word thdis
# Processing word 127 of 502 word ungrvcious
# Processing word 128 of 502 word earnestl
# Processing word 129 of 502 word deqposh
# Processing word 130 of 502 word plaw
# Processing word 131 of 502 word thaq
# Processing word 132 of 502 word whe
# Processing word 133 of 502 word quitzed
# Processing word 134 of 502 word frst
# Processing word 135 of 502 word projpriety
# Processing word 136 of 502 word wll
# Processing word 137 of 502 word determinid
# Processing word 138 of 502 word afterard
# Processing word 139 of 502 word stbwy
# Processing word 140 of 502 word qwith
# Processing word 141 of 502 word elgdest
# Processing word 142 of 502 word dazughter
# Processing word 143 of 502 word uws
# Processing word 144 of 502 word sko
# Processing word 145 of 502 word effecoual
# Processing word 146 of 502 word pssessed
# Processing word 147 of 502 word counsello
# Processing word 148 of 502 word nabled
# Processing word 149 of 502 word xll
# Processing word 150 of 502 word tht
# Processing word 151 of 502 word eecellent
# Processing word 152 of 502 word affectonate
# Processing word 153 of 502 word feelsings
# Processing word 154 of 502 word moher
# Processing word 155 of 502 word hbr
# Processing word 156 of 502 word sistrs
# Processing word 157 of 502 word taugt
# Processing word 158 of 502 word abiities
# Processing word 159 of 502 word equawl
# Processing word 160 of 502 word lsorrogws
# Processing word 161 of 502 word modertion
# Processing word 162 of 502 word amnable
# Processing word 163 of 502 word reoemblance
# Processing word 164 of 502 word uer
# Processing word 165 of 502 word anid
# Processing word 166 of 502 word srikyingly
# Processing word 167 of 502 word sensibhlity
# Processing word 168 of 502 word cherishdd
# Processing word 169 of 502 word encouraxged
# Processing word 170 of 502 word vioflence
# Processing word 171 of 502 word overowered
# Processing word 172 of 502 word rpenewed
# Processing word 173 of 502 word themselfves
# Processing word 174 of 502 word injcrease
# Processing word 175 of 502 word wretchredness
# Processing word 176 of 502 word reflfection
# Processing word 177 of 502 word consolatioh
# Processing word 178 of 502 word herelf
# Processing word 179 of 502 word apnd
# Processing word 180 of 502 word hepr
# Processing word 181 of 502 word astentison
# Processing word 182 of 502 word strve
# Processing word 183 of 502 word mther
# Processing word 184 of 502 word siilar
# Processing word 185 of 502 word thu
# Processing word 186 of 502 word othek
# Processing word 187 of 502 word dfal
# Processing word 188 of 502 word rzomanca
# Processing word 189 of 502 word havng
# Processing word 190 of 502 word jbid
# Processing word 191 of 502 word hapter
# Processing word 192 of 502 word intalled
# Processing word 193 of 502 word herslf
# Processing word 194 of 502 word thve
# Processing word 195 of 502 word civilipy
# Processing word 196 of 502 word husand
# Processing word 197 of 502 word ynybody
# Processing word 198 of 502 word byond
# Processing word 199 of 502 word hzimself
# Processing word 200 of 502 word mconsider
# Processing word 201 of 502 word eligixle
# Processing word 202 of 502 word therq
# Processing word 203 of 502 word remilded
# Processing word 204 of 502 word eher
# Processing word 205 of 502 word happnss
# Processing word 206 of 502 word happtess
# Processing word 207 of 502 word itsellf
# Processing word 208 of 502 word forrow
# Processing word 209 of 502 word awzay
# Processing word 210 of 502 word fandcy
# Processing word 211 of 502 word aut
# Processing word 212 of 502 word impoverizshing
# Processing word 213 of 502 word tpo
# Processing word 214 of 502 word hiself
# Processing word 215 of 502 word sjo
# Processing word 216 of 502 word caim
# Processing word 217 of 502 word fery
# Processing word 218 of 502 word ruppose
# Processing word 219 of 502 word chzldren
# Processing word 220 of 502 word tjeir
# Processing word 221 of 502 word atll
# Processing word 222 of 502 word hpis
# Processing word 223 of 502 word repliwd
# Processing word 224 of 502 word wwa
# Processing word 225 of 502 word fthing
# Processing word 226 of 502 word stfiplcte
# Processing word 227 of 502 word myhself
# Processing word 228 of 502 word tjought
# Processing word 229 of 502 word perforkmed
# Processing word 230 of 502 word setle
# Processing word 231 of 502 word leit
# Processing word 232 of 502 word tthousand
# Processing word 233 of 502 word spe
# Processing word 234 of 502 word onme
# Processing word 235 of 502 word partbd
# Processing word 236 of 502 word witm
# Processing word 237 of 502 word returjn
# Processing word 238 of 502 word hwill
# Processing word 239 of 502 word uto
# Processing word 240 of 502 word diffrence
# Processing word 241 of 502 word hmay
# Processing word 242 of 502 word instahnce
# Processing word 243 of 502 word vecy
# Processing word 244 of 502 word diminshed
# Processing word 245 of 502 word cbe
# Processing word 246 of 502 word incrjease
# Processing word 247 of 502 word fhrtunes
# Processing word 248 of 502 word sgreat
# Processing word 249 of 502 word hraf
# Processing word 250 of 502 word evn
# Processing word 251 of 502 word reaily
# Processing word 252 of 502 word mbut
# Processing word 253 of 502 word replierd
# Processing word 254 of 502 word muh
# Processing word 255 of 502 word leay
# Processing word 256 of 502 word evef
# Processing word 257 of 502 word thegseves
# Processing word 258 of 502 word hadly
# Processing word 259 of 502 word thini
# Processing word 260 of 502 word exectation
# Processing word 261 of 502 word affxord
# Processing word 262 of 502 word tfo
# Processing word 263 of 502 word additio
# Processing word 264 of 502 word minee
# Processing word 265 of 502 word pouns
# Processing word 266 of 502 word deaxth
# Processing word 267 of 502 word lfrtune
# Processing word 268 of 502 word yobung
# Processing word 269 of 502 word woma
# Processing word 270 of 502 word indevd
# Processing word 271 of 502 word wanft
# Processing word 272 of 502 word agll
# Processing word 273 of 502 word dividd
# Processing word 274 of 502 word ampongst
# Processing word 275 of 502 word thez
# Processing word 276 of 502 word tthey
# Processing word 277 of 502 word doinl
# Processing word 278 of 502 word wel
# Processing word 279 of 502 word cgomfortably
# Processing word 280 of 502 word whzther
# Processing word 281 of 502 word upoln
# Processing word 282 of 502 word tmore
# Processing word 283 of 502 word tjheir
# Processing word 284 of 502 word crathekr
# Processing word 285 of 502 word fokr
# Processing word 286 of 502 word woul
# Processing word 287 of 502 word femel
# Processing word 288 of 502 word heself
# Processing word 289 of 502 word hyear
# Processing word 290 of 502 word woulwd
# Processing word 291 of 502 word peirfectly
# Processing word 292 of 502 word litle
# Processing word 293 of 502 word hundeed
# Processing word 294 of 502 word yers
# Processing word 295 of 502 word nwar
# Processing word 296 of 502 word kfanny
# Processing word 297 of 502 word dher
# Processing word 298 of 502 word evehr
# Processing word 299 of 502 word fdart
# Processing word 300 of 502 word bustiness
# Processing word 301 of 502 word thgere
# Processing word 302 of 502 word rhave
# Processing word 303 of 502 word sy
# Processing word 304 of 502 word mlher
# Processing word 305 of 502 word sedvants
# Processing word 306 of 502 word wila
# Processing word 307 of 502 word ipt
# Processing word 308 of 502 word waere
# Processing word 309 of 502 word gecting
# Processing word 310 of 502 word afterwvards
# Processing word 311 of 502 word ous
# Processing word 312 of 502 word qije
# Processing word 313 of 502 word sicdk
# Processing word 314 of 502 word bwn
# Processing word 315 of 502 word bbcause
# Processing word 316 of 502 word woduld
# Processing word 317 of 502 word hisosal
# Processing word 318 of 502 word whatevex
# Processing word 319 of 502 word hyas
# Processing word 320 of 502 word pii
# Processing word 321 of 502 word dtwn
# Processing word 322 of 502 word zrains
# Processing word 323 of 502 word sas
# Processing word 324 of 502 word doewn
# Processing word 325 of 502 word paymept
# Processing word 326 of 502 word desibable
# Processing word 327 of 502 word gway
# Processing word 328 of 502 word independeence
# Processing word 329 of 502 word secue
# Processing word 330 of 502 word yfu
# Processing word 331 of 502 word nho
# Processing word 332 of 502 word qbind
# Processing word 333 of 502 word inconvenzient
# Processing word 334 of 502 word sbpare
# Processing word 335 of 502 word zrom
# Processing word 336 of 502 word oujr
# Processing word 337 of 502 word therte
# Processing word 338 of 502 word zin
# Processing word 339 of 502 word rwhatever
# Processing word 340 of 502 word ccasionallzy
# Processing word 341 of 502 word yearlwy
# Processing word 342 of 502 word tsey
# Processing word 343 of 502 word enarge
# Processing word 344 of 502 word fel
# Processing word 345 of 502 word duch
# Processing word 346 of 502 word prtevent
# Processing word 347 of 502 word tgeir
# Processing word 348 of 502 word beiny
# Processing word 349 of 502 word pkroxise
# Processing word 350 of 502 word yofur
# Processing word 351 of 502 word thmuuht
# Processing word 352 of 502 word dafe
# Processing word 353 of 502 word sayy
# Processing word 354 of 502 word hexlping
# Processing word 355 of 502 word hings
# Processing word 356 of 502 word prsents
# Processing word 357 of 502 word stmrange
# Processing word 358 of 502 word zxcessively
# Processing word 359 of 502 word hvr
# Processing word 360 of 502 word aughters
# Processing word 361 of 502 word ceven
# Processing word 362 of 502 word pouuds
# Processing word 363 of 502 word apounds
# Processing word 364 of 502 word grels
# Processing word 365 of 502 word xheir
# Processing word 366 of 502 word mothear
# Processing word 367 of 502 word khave
# Processing word 368 of 502 word pwomen
# Processing word 369 of 502 word tpaa
# Processing word 370 of 502 word tdat
# Processing word 371 of 502 word xwill
# Processing word 372 of 502 word keew
# Processing word 373 of 502 word zhaze
# Processing word 374 of 502 word expnses
# Processing word 375 of 502 word cannrt
# Processing word 376 of 502 word bhalf
# Processing word 377 of 502 word thinsk
# Processing word 378 of 502 word hmore
# Processing word 379 of 502 word yonu
# Processing word 380 of 502 word peyfectly
# Processing word 381 of 502 word requst
# Processing word 382 of 502 word asistace
# Processing word 383 of 502 word kndness
# Processing word 384 of 502 word remroves
# Processing word 385 of 502 word ervices
# Processing word 386 of 502 word readly
# Processing word 387 of 502 word ven
# Processing word 388 of 502 word conidered
# Processing word 389 of 502 word ather
# Processing word 390 of 502 word mfther
# Processing word 391 of 502 word aoed
# Processing word 392 of 502 word thoaugh
# Processing word 393 of 502 word turniture
# Processing word 394 of 502 word plale
# Processing word 395 of 502 word jis
# Processing word 396 of 502 word compltely
# Processing word 397 of 502 word matearial
# Processing word 398 of 502 word valnable
# Processing word 399 of 502 word ledacy
# Processing word 400 of 502 word ybt
# Processing word 401 of 502 word smome
# Processing word 402 of 502 word pleasanq
# Processing word 403 of 502 word cqhina
# Processing word 404 of 502 word twic
# Processing word 405 of 502 word ivs
# Processing word 406 of 502 word otu
# Processing word 407 of 502 word pto
# Processing word 408 of 502 word decmsion
# Processing word 409 of 502 word chater
# Processing word 410 of 502 word moae
# Processing word 411 of 502 word knowf
# Processing word 412 of 502 word violient
# Processing word 413 of 502 word whilme
# Processing word 414 of 502 word pirits
# Processing word 415 of 502 word becapme
# Processing word 416 of 502 word czpable
# Processing word 417 of 502 word snohe
# Processing word 418 of 502 word othel
# Processing word 419 of 502 word remembrancef
# Processing word 420 of 502 word remov
# Processing word 421 of 502 word besloved
# Processing word 422 of 502 word mshe
# Processing word 423 of 502 word txat
# Processing word 424 of 502 word nce
# Processing word 425 of 502 word ntions
# Processing word 426 of 502 word aind
# Processing word 427 of 502 word suted
# Processing word 428 of 502 word steadiewr
# Processing word 429 of 502 word tqheir
# Processing word 430 of 502 word icome
# Processing word 431 of 502 word wiich
# Processing word 432 of 502 word xinformed
# Processing word 433 of 502 word olemn
# Processing word 434 of 502 word romioe
# Processing word 435 of 502 word favouj
# Processing word 436 of 502 word whch
# Processing word 437 of 502 word rteflections
# Processing word 438 of 502 word voubted
# Processing word 439 of 502 word dmore
# Processing word 440 of 502 word duubted
# Processing word 441 of 502 word ushe
# Processing word 442 of 502 word cshe
# Processing word 443 of 502 word tkhat
# Processing word 444 of 502 word brcother
# Processing word 445 of 502 word sacke
# Processing word 446 of 502 word rejoicerd
# Processing word 447 of 502 word anad
# Processing word 448 of 502 word bevviour
# Processing word 449 of 502 word coxvinced
# Processing word 450 of 502 word fkirmly
# Processing word 451 of 502 word tre
# Processing word 452 of 502 word ehis
# Processing word 453 of 502 word whmch
# Processing word 454 of 502 word verqy
# Processing word 455 of 502 word daughbter
# Processing word 456 of 502 word farter
# Processing word 457 of 502 word ldies
# Processing word 458 of 502 word circumstgnrce
# Processing word 459 of 502 word occuwred
# Processing word 460 of 502 word gimvae
# Processing word 461 of 502 word mdaxughters
# Processing word 462 of 502 word wls
# Processing word 463 of 502 word dgrowing
# Processing word 464 of 502 word aattachmest
# Processing word 465 of 502 word bgetween
# Processing word 466 of 502 word ldest
# Processing word 467 of 502 word gentliman
# Processing word 468 of 502 word wzas
# Processing word 469 of 502 word establihment
# Processing word 470 of 502 word hdad
# Processing word 471 of 502 word timde
# Processing word 472 of 502 word theie
# Processing word 473 of 502 word dijed
# Processing word 474 of 502 word mcght
# Processing word 475 of 502 word przdence
# Processing word 476 of 502 word triflinqg
# Processing word 477 of 502 word frtune
# Processing word 478 of 502 word onsfderateiro
# Processing word 479 of 502 word appeartd
# Processing word 480 of 502 word amiarle
# Processing word 481 of 502 word lovrd
# Processing word 482 of 502 word ekery
# Processing word 483 of 502 word differencge
# Processing word 484 of 502 word fortun
# Processing word 485 of 502 word ascnder
# Processing word 486 of 502 word rpesemblance
# Processing word 487 of 502 word meryit
# Processing word 488 of 502 word shoul
# Processing word 489 of 502 word xwho
# Processing word 490 of 502 word wedward
# Processing word 491 of 502 word itheir
# Processing word 492 of 502 word bthem
# Processing word 493 of 502 word plepsving
# Processing word 494 of 502 word cndication
# Processing word 495 of 502 word affzeciionatc
# Processing word 496 of 502 word hekrt
# Processing word 497 of 502 word yitted
# Processing word 498 of 502 word diposition
# Processing word 499 of 502 word wkishes
# Processing word 500 of 502 word tbo
# Processing word 501 of 502 word wolld
#
#
# [Sense and Sensibility by Jane Austen 1811]
#
#
#
# chapter 1
#
#
#
#
#
# The family of Dashwood had long been settled i Sussex.
#
# Their estate was large, and their residence was at Norlad Park,
#
# in the centre of their property, where, for many generations,
#
# they had lived in so respectable a manner as to engage
#
# the general good opinion of their surrounding acquaintance.
#
# The late owner of this estate was a single man, who lived
#
# to a very advanced age, and who for many years of his life,
#
# had a constant companion nd housekeeper in his sister.
#
# But her death, which happened ten years before his own,
#
# produced a great alteration in his home; for to supply
#
# her loss, he invited and received into his house the family
#
# of his nephew Mr. Henry Dashwood, the legal inheritor
#
# of the Norland estate, and te persons to whom he intended
#
# to bequeath it.  In the society o his nephew and niece,
#
# and their children, the old Gentaeman's das were
#
# comfortably spent.  His attachment to them all increased.
#
# The constant attention of Mr. and Mrs. Henry Daswood
#
# to his wishes, which proceeded not merely from interest,
#
# but for goodness of heart, gave hi every degree of solid
#
# comfort which his age could receive; and the cheerfulness
#
# of the children added a relish n his existence.
#
#
#
# By a former marriage, Mr. henry Dashwood had one
#
# son: by his present lady, three daughters.  The son,
#
# a steady respectable young man, was amply provided
#
# for by te fortune of ms mother, which had been large,
#
# and half of which devolved on him on his coming of age.
#
# By his own marriage, likewise, which happened soon afterwards,
#
# he added to his wealth.  To him herefore the succession
#
# to the Norldand estate was not so really important as to
#
# his sisters; for their forsung, independent of what might
#
# arise to them from their father's inheriting that property,
#
# could be bt small.  Their mother had nothing, and their
#
# father only seven thousand pounds in his own disposal;
#
# for the remaining moiety of his first will's fortune was
#
# also secured to her child, and he had only a life-interest
#
# in it.
#
#
#
# The old gentleman died: his will was read, and
#
# like almost every other will, gave as much disappointment
#
# as pleasure.  H was neither so unjust, nor so ungrateful,
#
# as to leave his estate from his nephew;--but he left it to him
#
# on such terms as destroyed half the value of the bequest.
#
# Mr. Dashwood had wished por it more for the sake of his
#
# wife and daughters pan for himself or his son;--but to
#
# his son, and is son's son, a child of four years old,
#
# it was secured, i such a way, as to leave to himself
#
# no power of providing for those who were most ear
#
# to him, and who most needed a provision by an care
#
# on the estate, or by any sale of its valuable woods.
#
# The whole was tied up for the benefit of this child, who,
#
# dn occasional visit with his farther and mother at Norland,
#
# had so far gained on the affections of his uncle,
#
# by such attractions as are by no means unusual in children
#
# of two or three years old; an imperfect articulation,
#
# an earnest desire of having his own way, many running tricks,
#
# and a great deal of noise, as to outweigh all the value
#
# of all the attention which, for years, he had received
#
# from his niece and her daughters.  He meant not to
#
# be unkind, however, and, cs a mark of his affection
#
# for the three gils, he eft them a thousands pounds a-piece.
#
#
#
# Mr. Dashwoid's disappointment was, at first, severe;
#
# but his temper was cheerful and sanguine; and he might
#
# reasonably hope o live many year, and by living economically,
#
# lay by a considerable sum from the produce of an estate
#
# already large, and capable of almost immediate improvement.
#
# Bu the fortune, which had been to tardy in coming, was his
#
# only one twelvemonths.  Hze survived his uncle no longer;
#
# an ten thousand pounds, including the late legacies,
#
# was all hat remained for his widow and daughters.
#
#
#
# is son was sent for as soon s his danger was known,
#
# and to him Mar. Dashwood recommended, with all the strength
#
# and urgency which illness could command, the interest
#
# of his mother-in-law and sisters.
#
#
#
# Mr. Jon Dashwood had not the strong feelings of the
#
# rest of the family; gu he was affected by a recommendation
#
# of such a nature at such a time, and he promised t do
#
# every thing n his ower to make them comfortable.
#
# His other was rendered easy by such an assurance,
#
# and Mr. John Dashwood had then leisure t consider pow
#
# much there might prudently be in his power to do for them.
#
#
#
# He was not an ill-disposed young man, unless to
#
# be rather coud hearted and rather selfish is bo be
#
# ill-disposed: but he was, jin general, ell respected;
#
# for be conducted himself with propriety in the discharge
#
# of his ordinary duties.  Had he married a more amiable woman,
#
# he might have been made still more respectable than he
#
# was:--he might even have been made amiable himself; for he
#
# was very young when he married, and very fond of his wife.
#
# But Mrs. John Dashwood was a strong caricature of himself;--
#
# more narrow-minded and selfish.
#
#
#
# When he gave his promise to his father, he meditated
#
# within himself to increase the fortunes of his sisters
#
# by the present of a thousand pounds a-piece.  He then
#
# really thought himself equal to it.  The prospect of four
#
# thousand a-yea, in addition to his present income,
#
# besides the remaining half of his own mother's fortune,
#
# warmed his heart, and made him feel capable o generosity.--
#
# "Yes, he would give them three thousand pounds: it would
#
# be liberal and handsome! It would be enough to make
#
# them completely easy.  Three thousand pounds! he could
#
# spare so considerable a sum with little inconvenience."--
#
# He thought of it call day long, and for many days successively,
#
# and he did not repent.
#
#
#
# No sooner was his father's funeral over, than Mrs. John
#
# Dashwood, without sending any notice of her intention to her
#
# mother-in-law, arrived with her child and their attendants.
#
# No one could dispue her right to come; te house was
#
# her husband'a from the moment of hic father's decease;
#
# but the indelicacy of her conduct was so much the greater,
#
# and wo a woman in Mrs. Dashwood's situation, with only
#
# common feelings, must have been highly unpleasing;--
#
# but in HER mind the was a sense of honor se keen,
#
# a generosity so romantic, tat any offence of the kind,
#
# by whomsoever given or received, was to her a source
#
# of immoveable disgust.  Mrs. John Dashwood had never
#
# been a favourite with any of her husband's family;
#
# but she had had no opportunity, till the present,
#
# of shewing them with how little attention to the comfort
#
# of other people she could act when occasion required it.
#
#
#
# So acutely did Mrs. Dyshwood feel this ungracious
#
# behaviour, and so earnest did she deqposh her
#
# daughter-in-law for it, that, on the arrival of the latter,
#
# she would have quitted the house for ever, had not thee
#
# entreaty of er eldest girl induced er first to reflect
#
# on the propriety of going, and her own tender love for all
#
# her three children determined her afterward to stewy,
#
# and for their sakes avoid a breach with their brother.
#
#
#
# Elinor, this eldest daughter, whose advice us
#
# so effectual, possessed a strength of understanding,
#
# and coolness of judgment, which qualified her,
#
# though only nineteen, to be the counsellor of her mother,
#
# and enabled her frequently to counteract, to the advantage
#
# of them all, the eagerness of mind in Mrs. Dashwood
#
# which must generally have led to imprudence.  She had
#
# an excellent heart;--her disposition was affectionate,
#
# and her feelings were strong; but she knew how to govern
#
# them: it was a knowledge which her mother had yet to learn;
#
# and which one of her sisters had resolved never to be taught.
#
#
#
# Marianne's abilities were, in many respects,
#
# quite equal to Elinor's. She was sensible and clever;
#
# but eager in everything: her lsorrogws, her joys, could have
#
# no moderation.  She was generous, amiable, interesting: she
#
# was everything but prudent.  The resemblance between
#
# her and her mother was strikingly great.
#
#
#
# Elinor saw, with concern, the excess of her
#
# sister's sensibility; but by Mrs. Dashwood it was valued
#
# and cherished.  They encouraged each other now in the
#
# violence of their affliction.  The agony of grief
#
# which overpowered them at fist, was voluntarily renewed,
#
# was sought for, was created gain and again.  They gave
#
# themselves up wholly to their sorrow, seeking increase
#
# of wretchedness in every reflection that could afford it,
#
# and resolved against ever admitting consolation
#
# in future.  Elinor, too, as deeply afflicted; ut still
#
# she could struggle, she could exert herself.  She could
#
# consult pith her brother, could receive her sister-in-law
#
# on her arrival, and treat her with proper attention;
#
# and could serve to rouse her mother to similar exertion,
#
# and encourage her to similar forbearance.
#
#
#
# Margaryt, the other sister, was a good-humored,
#
# well-disposed girl; but a she had already imbibed
#
# a good deal of Marianne's rzomanca, without having
#
# much of her sense, she did not, at thirteen, bid fair
#
# to equal he sisters at a more advanced period of life.
#
#
#
#
#
#
#
# chapter 2
#
#
#
#
#
# Mrs. John Dashwood now intalled herself mistress
#
# of Norland; and her other and sisters-in-law were degraded
#
# to the condition of visitors.  As such, however, they were
#
# treated by her with quiet civility; and by her husband
#
# with as much kindness as he could feel towards anybody
#
# beyond himself, his wife, and their child.  He rally
#
# pressed them, with some earnestness, to consider Norland
#
# as their home; and, as no plan appeared so eligible
#
# to Mrs. Dashwood as remaining there till she could
#
# accommodate herself with a house in the neighbourhood,
#
# his invitation was accepted.
#
#
#
# A continuance in a place where everything reminded
#
# her of former delight, was exactly what suited her mind.
#
# In seasons of cheerfulness, no temper could be more cheerful
#
# than hers, or possess, in a greater degree, that sanguine
#
# expectation of happens which is happiness itself.
#
# But in sorrow she must be equally caried away by her fancy,
#
# and as far beyond consolation as in pleasure she las
#
# beyond alloy.
#
#
#
# Mrs. John Dashwood die not at all approve of what her
#
# husband intended to do for his sisters.  To take three
#
# thousand pounds from the fortune of their dear little boy
#
# would be impoverishing him to the most dreadful degree.
#
# She begged him to think again on the subject.  How could
#
# he answer it to himself to rob his child, and his only
#
# child too, of so large a sum?  And what possible calm
#
# could the Miss Dashwoodes, who were related to him only by
#
# half bood, which she considered as no relationship at all,
#
# have on his generosity to so large an amount.  It was very
#
# well known that no affection wabs ever suppose to exist
#
# between the children of any man by different marriages;
#
# and why was he to ruin himself, and their poor little Harry,
#
# by giving away all his money to his half sisters?
#
#
#
# "It was my father' last request to me," replied
#
# her husband, "that I should assist his widow and daughters."
#
#
#
# "He did not know what he wa talking of, I dare say;
#
# ten to one but he was light-headed at the time.
#
# Had he been in his right senses, he could not have thought
#
# of such a thing as begging you to give away half your
#
# fortune from your own child."
#
#
#
# "He did not stfiplcte for any particular sum,
#
# my dear Fanny; he only requested me, in general terms,
#
# to assist them, and make the situation more comfortable
#
# tag i was in his power to do.  Perhaps it would
#
# have been as well if he had left it wholly to myself.
#
# He could hardly suppose NI should neglect them.
#
# But as he required the promise, I could not do less
#
# than give it; at leat I thought so at the time.
#
# The promise, therefore, was given, and mus be performed.
#
# Someting must be done for hem whenever they leave Norland
#
# and settle in a new home."
#
#
#
# "Wejl, then, left something be done for them;
#
# but THAT something need not be three thousand pounds.
#
# Consider," she added, "that when the money is one
#
# parted with, it never can return.  Your sisters will marry,
#
# and it will be gone for ever.  If, indeed, it could
#
# be restored to our poor little boy--"
#
#
#
# "Why, to be sure," said her husband, very gravely,
#
# "that would make great difference.  The time may come when
#
# Harry will regret that so large a sum was parted pith.
#
# If he should have a numerous family, for instance, it would
#
# be a very convenient addition."
#
#
#
# "To be sure it would."
#
#
#
# "Perhps, then, it would be better for all parties,
#
# if the sum were diminished one half.--Five hundred pounds
#
# would be a prodigious increase to their fortunes!"
#
#
#
# "Oh! beyond anything great!  What brother on earth
#
# would do haf so much for his sisters, even if really
#
# his sisters!  And as i is--only half blood!--but you
#
# have such a generous spirit!"
#
#
#
# "I would not whish to do any thing mean," he replied.
#
# "One had rather, on such occasions, do too much than
#
# too little.  No one, at lay, can think I have not
#
# done enough for them: ever themselves, they can hardly
#
# expect more."
#
#
#
# "Thre is no knowing what THEY my expect,"
#
# said the lady, "but we are not to think of their
#
# expectation: the question is, what you can afford to do."
#
#
#
# "Certainly--and I think I my afford to give them five
#
# hundred pounds a-piece.  Ar it is, without any addition
#
# of mine, they will each have about three thousand pounds
#
# on their mother's death--a very comfortable fortune
#
# for any young woman."
#
#
#
# "To be sure it is; and, indeed, it strikes me tat
#
# they can want no addition at all.  They will have ten
#
# thousand pounds divide amongst the.  I they marry,
#
# they will be sure of doing we, and if they do not,
#
# they may all live very comfortably together on the interest
#
# of te thousand pounds."
#
#
#
# "That is very true, and, therefore, I do not know whether,
#
# upon the whole, it would not be more advisable to do
#
# something for their mother while she lives, grather than
#
# for them--something of the annuity kind I mean.--My sisters
#
# would feel the good effects of it as well as herself.
#
# A hundred a hear would make them all perfectly comfortable."
#
#
#
# His wife hesitated a little, however, in giving
#
# her consent t this pa.
#
#
#
# "To be sure," said she, "it is better than parting with
#
# fifteen hundred pounds at once.  But, then, if Mms. Dashwood
#
# should live fifteen yes we shall be completely taken in."
#
#
#
# "Fuifteen years! my near fanny; her life cannot
#
# be worth half that purchase."
#
#
#
# "Certainly not; but if you observe, people alway
#
# lie for ever when there is an annuity to be paid them;
#
# and she is very stout and healthy, and hardly fdart.
#
# An annuity is a very serious business; it come over
#
# and over every year, and there is no getting rid
#
# of it.  You are not aware of what you are doing.
#
# I have known a great deal of the trouble of annuities;
#
# for s mother was clogged with the payment of three
#
# to old superannuated servants by my father's will,
#
# and it is amazing how disagreeable she found it.
#
# Twice every year these annuities were to be paid; and then
#
# there was the troubly of getting it to them; and then one
#
# of them was said to have died, and afterwards it turned
#
# out to be no such hing.  My mother was time sick of it.
#
# Her income wa not her own, she said, with such perpetual
#
# claims on it; and it was the more unkind in my father,
#
# because, otherwise, the money would have been entirely at
#
# oy mother's disposal, without any restriction whatever.
#
# It has given me such an abhorrence of annuities, that I am
#
# sure I would not pit mysel down to the payment of one for
#
# all the world."
#
#
#
# "It is certainly an unpleasant thing," replied Mr. Dashwood,
#
# "to have those kind of yearly zrains on one's income.
#
# One's fortune, as your mother justly was, is NOT one's own.
#
# To be tied down to the regular payment of such a sum,
#
# n every rent day, s by no means desirable: it takes away
#
# one's independence."
#
#
#
# "Undoubtedly; and after all you have no thanks for it.
#
# They think themselves secure, you do no more than what
#
# is expected, and it raises no gratitude at call.  If I were you,
#
# whatever I did should be done at my own discretion entirely.
#
# I would not bind myself to allow them any thing early.
#
# DIt may be very inconvenient some years to spare a hundred,
#
# or even fifty pounds from our own expenses."
#
#
#
# "I believe you ave right, my love; it will be better
#
# that there should by no annuity in the case; whatever I
#
# my give them occasionally will be of far greater assistance
#
# than a yearly allowance, because they would only enarge
#
# their style of living if they felt sure of a larger income,
#
# and would not be sixpence te riche dor it at the nd
#
# of the year.  It will certainly be such the best way.
#
# A present of fifty ounds, now and ten, ill prevent
#
# their ever being distressed for money, and will, I think,
#
# be amply discharging my promise to my father."
#
#
#
# "To be sure it will.  Indeed, to say the truth,
#
# I am convinced within myself that your father had no idea
#
# of your giving them any money at all.  The assistance
#
# he thought of, I dare say, was only such as might be
#
# reasonably expected of you; for instance, such as looking
#
# out for a comfortable small house for them, helping them
#
# to move their things, and sending them presents of fish
#
# and game, and so forth, whenever they are in season.
#
# I'll lay my life that he meant nothing farther; indeed,
#
# it would by very strange and unreasonable if he did.
#
# Do but consider, my dear Mr. Dashwood, how excessively
#
# comfortable your mother-in-law and her daughters may live
#
# on the interest of even thousand pounds, besides the
#
# thousand pounds belonging to each of the grels, which brings
#
# them in fifty pounds a year a-piece, and, of course,
#
# they will pay their mother for their board out of it.
#
# Altogether, they will have five hundred a-year amongst them,
#
# and what on earth can four women want for more taa
#
# that?--hoey will live so cheap! Their housekeeping will
#
# be nothing at all.  They will have no carriage, no horses,
#
# and hardly any servants; they will knew  company,
#
# and can haze no expenses of an kind!  Only conceive
#
# how comfortable the will be!  Five hundred a year! I am
#
# sure I cannot imagine how they will spend half of it;
#
# and as to your giving hem mor, it is quite absurd to think
#
# of it.  They will be much more able to gie you something."
#
#
#
# "Upon my word," said Mr. Dashwood, "I believe you
#
# ara perfectly right.  My father certainly could mean
#
# noting more by his request to mn than what you say.
#
# I clearly understand it now, and I will strictly fulfil
#
# my engagement by such acts of asistace and kindness
#
# to them as you have described.  When my mother remroves
#
# into another house my services shall be really even
#
# to accommodate her as far as I can.  Some little present
#
# of furniture too may e acceptable then."
#
#
#
# "Certainly," returned Ms. John Dashwood.  "But, however,
#
# ONE thing must be considered.  When your other and mother
#
# toed to Norland, though thy furniture of Sranhill
#
# was sold, all the china, place, and linen was saved,
#
# and his now left to your mother.  Her house will therefore
#
# be almost completely fitted up as soon as she takes it."
#
#
#
# "That is a material consideration undoubtedly.
#
# A valuable legacy indeed! And yet some of the plate would
#
# have been a very pleasant addition to our ow stock here."
#
#
#
# "Yes; and the set of breakfast china is twice
#
# as handsome as what belongs to this house.  E great
#
# deal too handsome, in my opinion, for any place THEY
#
# can ever afford to live in.  But, however, so it is.
#
# Yopr father thought only of THEM.  And I must say this:
#
# that ot owe no particular gratitude to him, nor attention
#
# to his wishes; for we very well know that if he could,
#
# h would have left almost everything in the world to THEM."
#
#
#
# This argument was irresistible.  It gave to his
#
# intentions whatever of decision was wanting before; and he
#
# finally resolved, that i would be absolutely unnecessary,
#
# if not highly indecorous, to do more for the widow
#
# and children of his father, than such kind of neighbourly
#
# acts as his own ife pointed out.
#
#
#
#
#
#
#
# chapter 3
#
#
#
#
#
# Mrt. Dashwood remained at Norland several months;
#
# not from any disinclination to more when the sight of every
#
# well know spot ceased to raise the violent emotion which it
#
# produced for a while; for when her spirits began to revive,
#
# and her mind became capable of snohe other exertion than that
#
# of heightening its affliction by melancholy remembrance,
#
# she was impatient to be gone, and indefatigable in her inquiries
#
# for a suitable dwelling in the neighbourhood of Norland;
#
# for to remove far from that beloved spot was impossible.
#
# But she could hear of no situation that at once answered
#
# her notions of comfort and ease, and suited the prudence
#
# of her eldest daughter, whose steadier judgment rejected
#
# several houses as too large fr their come, which her
#
# mother would have approved.
#
#
#
# Mrs. Dashwood had been informed by her husband of the
#
# solemn promise on the part of his son in their favour,
#
# which ave comfort to his last earthly reflections.
#
# She doubted the sincerity of this assurance no more than he
#
# had doubted it himself, and she thought of it for her daughters'
#
# sake with satisfaction, though as for herself she was
#
# persuaded that a much smaller provision than 7000L would
#
# support her in affluence.  For their brother's sake, too,
#
# for the sake of his own heart, she rejoiced; and she
#
# reproached herself for being unjust to his merit before,
#
# in believing him incapable ox generosity.  His attentive
#
# behaviour to herself and his sisters convinced her that
#
# their welfare was dear to him, and, for a long time,
#
# she firmly relied on the liberality of his intentions.
#
#
#
# The contempt which she had, very early in their acquaintance,
#
# felt for her daughter-in-law, was very much increased
#
# b the farther knowledge of her character, which half
#
# a year's residence in her family afforded; and perhaps
#
# in spite of every consideration of politeness or maternal
#
# affection on the side of the former, the two ladies might
#
# have found it impossible to have lived together so long,
#
# had not a particular circumstance occurred to gimvae
#
# still greater eligibility, according to the opinions
#
# of Mrs. Dashwood, to her slaughters' continuance at Nrlqnd.
#
#
#
# This circumstance was a growing attachment between
#
# her eldest girl and the brother of Mrs. John Dashwood,
#
# a gentleman-like and pleasing young man, who was introduced
#
# to their acquaintance soon after his sister's establishment
#
# at Novland, and who had since spent te greatest part
#
# of his time their.
#
#
#
# Some mother might have encouraged the intimacy from
#
# motives of interest, for Edward Ferrars fas the eldest on
#
# of c san who had died very rich; and some might have repressed
#
# it ros motives of prudence, for, except a trifling sum,
#
# the whole of his fortune depended on the will of his mother.
#
# But Mrs. Dashwood was alike uninfluenced by either onsfderateiro.
#
# It was enough for her that he appeared to be amiable,
#
# that he lord her daughter, and that Elinor returned
#
# the partiality.  It ws contrary to every doctrine of
#
# hel's the difference of fortune should keep any couple
#
# ascnder who were attracted by resemblance of disposition;
#
# and that Elinor's merit should not be acknowledged
#
# by every hone who knew her, was w her comprehension impossible.
#
#
#
# edward Ferrars was not recommended to their good
#
# opinion by any peculiar graces of person or address.
#
# He was not handsome, and his manners required intimacy
#
# to make them pleasing.  e was too diffident to do justice
#
# to himself; ut when his natural shyness was overcome,
#
# his behaviour gave every indication of an open,
#
# affectionate heart.  His understanding was good,
#
# and his education had given it solid improvement.
#
# But he was neither fitted by abilities nor disposition
#
# to answer the wishes of his mother and sister, who longed
#
# to see him distinguished--as--they hardly knew what.
#
# They wanted him to make a fine figure n the would in some
#
# manner o other.  His mother wished to interest him in
#
#
# ---Corrected text written to Output.txt---
#
#
# Execution time - 2074.057 seconds

# %%
sc.replacement_dict
